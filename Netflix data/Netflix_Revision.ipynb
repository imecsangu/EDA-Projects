# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import glob

# %%
df = glob.glob('*.csv')
data = vars() # vars will be used to convert string format to a variable format to read files easily.
for i in df:
    print(i[:-4])
    data[i[:-4]] = pd.read_csv(i)
# Out:
# best_movies_netflix
# best_movie_by_year_netflix
# best_shows_netflix
# best_show_by_year_netflix
# raw_credits
# raw_titles

# %%
best_movies_netflix
# Out:
#                                         title  release_year  score  \
# 0    David Attenborough: A Life on Our Planet          2020    9.0
# 1                                   Inception          2010    8.8
# 2                                Forrest Gump          1994    8.8
# 3                                  Anbe Sivam          2003    8.7
# 4                          Bo Burnham: Inside          2021    8.7
# ..                                        ...           ...    ...
# 382                                  The Trip          2021    6.9
# 383                                  The Dirt          2019    6.9
# 384                                   Top Gun          1986    6.9
# 385                               Radhe Shyam          2022    6.9
# 386                       Sorry to Bother You          2018    6.9
#
#      number_of_votes  duration   main_genre main_production
# 0              31180        83  documentary              GB
# 1            2268288       148        scifi              GB
# 2            1994599       142        drama              US
# 3              20595       160       comedy              IN
# 4              44074        87       comedy              US
# ..               ...       ...          ...             ...
# 382            19706       113       comedy              NO
# 383            47603       108        drama              US
# 384           329656       110        drama              US
# 385            21328       138      romance              IN
# 386            75653       111      fantasy              US
#
# [387 rows x 7 columns]

# %%
best_movies_netflix.shape
# Out:
# (387, 7)

# %%
best_movies_netflix.isnull().any()
# Out:
# title              False
# release_year       False
# score              False
# number_of_votes    False
# duration           False
# main_genre         False
# main_production    False
# dtype: bool

# %%
best_movies_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            387 non-null    object
#  1   release_year     387 non-null    int64
#  2   score            387 non-null    float64
#  3   number_of_votes  387 non-null    int64
#  4   duration         387 non-null    int64
#  5   main_genre       387 non-null    object
#  6   main_production  387 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 21.3+ KB

# %%
best_movies_netflix.describe()
# Out:
#        release_year       score  number_of_votes    duration
# count    387.000000  387.000000     3.870000e+02  387.000000
# mean    2011.023256    7.509044     1.365206e+05  123.395349
# std       10.813874    0.441906     2.342114e+05   28.371632
# min     1954.000000    6.900000     1.013900e+04   28.000000
# 25%     2008.000000    7.100000     2.051250e+04  103.500000
# 50%     2014.000000    7.400000     4.520000e+04  122.000000
# 75%     2018.000000    7.800000     1.534855e+05  139.000000
# max     2022.000000    9.000000     2.268288e+06  229.000000

# %%
best_movie_by_year_netflix
# Out:
#                                              title  release_year  score  \
# 0                                  White Christmas          1954    7.5
# 1                             The Guns of Navarone          1961    7.5
# 2                                     My Fair Lady          1964    7.8
# 3                                 Bonnie and Clyde          1967    7.7
# 4                                      Dirty Harry          1971    7.7
# 5                                     The Exorcist          1973    8.1
# 6                  Monty Python and the Holy Grail          1975    8.2
# 7                                      Taxi Driver          1976    8.3
# 8                                    Life of Brian          1979    8.0
# 9                                  The Blue Lagoon          1980    5.8
# 10                                           Annie          1982    6.6
# 11                                       Christine          1983    6.7
# 12                     Once Upon a Time in America          1984    8.3
# 13                                     Stand by Me          1986    8.1
# 14                               Full Metal Jacket          1987    8.3
# 15                         When Harry Met Sally...          1989    7.7
# 16                                      Awakenings          1990    7.8
# 17                                         My Girl          1991    6.9
# 18                         A River Runs Through It          1992    7.2
# 19                               Menace II Society          1993    7.5
# 20                                    Forrest Gump          1994    8.8
# 21                                       Desperado          1995    7.1
# 22                                   Happy Gilmore          1996    7.0
# 23  Neon Genesis Evangelion: The End of Evangelion          1997    8.0
# 24                             Saving Private Ryan          1998    8.6
# 25                               Girl, Interrupted          1999    7.3
# 26                                     The Patriot          2000    7.2
# 27               Lagaan: Once Upon a Time in India          2001    8.1
# 28                               Road to Perdition          2002    7.7
# 29                                        Big Fish          2003    8.0
# 30                                          Swades          2004    8.1
# 31                             Memoirs of a Geisha          2005    7.3
# 32                                 Rang De Basanti          2006    8.1
# 33                             Like Stars on Earth          2007    8.3
# 34                                          Ip Man          2008    8.0
# 35                                        3 Idiots          2009    8.4
# 36                                       Inception          2010    8.8
# 37                                         Warrior          2011    8.2
# 38                                Django Unchained          2012    8.4
# 39                                            Rush          2013    8.1
# 40                                           Queen          2014    8.2
# 41                                        Drishyam          2015    8.2
# 42                                          Dangal          2016    8.4
# 43                      Bāhubali 2: The Conclusion          2017    8.2
# 44                                       Andhadhun          2018    8.2
# 45                 Dave Chappelle: Sticks & Stones          2019    8.4
# 46        David Attenborough: A Life on Our Planet          2020    9.0
# 47                              Bo Burnham: Inside          2021    8.7
# 48                             The Tinder Swindler          2022    7.2
#
#      main_genre main_production
# 0       romance              US
# 1           war              US
# 2         drama              US
# 3         drama              US
# 4      thriller              US
# 5        horror              US
# 6        comedy              GB
# 7         crime              US
# 8        comedy              GB
# 9       romance              US
# 10        drama              US
# 11       horror              US
# 12        drama              US
# 13        drama              US
# 14        drama              GB
# 15      romance              US
# 16        drama              US
# 17       comedy              US
# 18        drama              US
# 19        drama              US
# 20        drama              US
# 21     thriller              US
# 22       comedy              US
# 23        scifi              JP
# 24        drama              US
# 25        drama              US
# 26        drama              DE
# 27        drama              IN
# 28     thriller              US
# 29        drama              US
# 30        drama              IN
# 31        drama              FR
# 32       comedy              IN
# 33        drama              IN
# 34        drama              HK
# 35       comedy              IN
# 36        scifi              GB
# 37        drama              US
# 38      western              US
# 39        drama              US
# 40        drama              IN
# 41     thriller              IN
# 42       action              IN
# 43      fantasy              IN
# 44     thriller              IN
# 45       comedy              US
# 46  documentary              GB
# 47       comedy              US
# 48        crime              GB

# %%
best_movie_by_year_netflix.shape
# Out:
# (49, 5)

# %%
best_movie_by_year_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            49 non-null     object
#  1   release_year     49 non-null     int64
#  2   score            49 non-null     float64
#  3   main_genre       49 non-null     object
#  4   main_production  49 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.0+ KB

# %%
best_movie_by_year_netflix.isnull().any()
# Out:
# title              False
# release_year       False
# score              False
# main_genre         False
# main_production    False
# dtype: bool

# %%
best_movie_by_year_netflix.describe()
# Out:
#        release_year      score
# count     49.000000  49.000000
# mean    1996.102041   7.871429
# std       17.335230   0.632785
# min     1954.000000   5.800000
# 25%     1984.000000   7.500000
# 50%     1998.000000   8.100000
# 75%     2010.000000   8.300000
# max     2022.000000   9.000000

# %%
best_shows_netflix
# Out:
#                           title  release_year  score  number_of_votes  \
# 0                  Breaking Bad          2008    9.5          1727694
# 1    Avatar: The Last Airbender          2005    9.3           297336
# 2                    Our Planet          2019    9.3            41386
# 3                  Kota Factory          2019    9.3            66985
# 4                The Last Dance          2020    9.1           108321
# ..                          ...           ...    ...              ...
# 241                 Evil Genius          2018    7.5            27516
# 242              13 Reasons Why          2017    7.5           282373
# 243                       Lupin          2021    7.5           100575
# 244          All of Us Are Dead          2022    7.5            41393
# 245     I Am Not Okay with This          2020    7.5            56459
#
#      duration  number_of_seasons   main_genre main_production
# 0          48                  5        drama              US
# 1          24                  3        scifi              US
# 2          50                  1  documentary              GB
# 3          42                  2        drama              IN
# 4          50                  1  documentary              US
# ..        ...                ...          ...             ...
# 241        48                  1        crime              US
# 242        58                  4        drama              US
# 243        46                  3        crime              FR
# 244        61                  1       action              KR
# 245        21                  1       comedy              US
#
# [246 rows x 8 columns]

# %%
best_shows_netflix.shape
# Out:
# (246, 8)

# %%
best_shows_netflix.isnull().any()
# Out:
# title                False
# release_year         False
# score                False
# number_of_votes      False
# duration             False
# number_of_seasons    False
# main_genre           False
# main_production      False
# dtype: bool

# %%
best_shows_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              246 non-null    object
#  1   release_year       246 non-null    int64
#  2   score              246 non-null    float64
#  3   number_of_votes    246 non-null    int64
#  4   duration           246 non-null    int64
#  5   number_of_seasons  246 non-null    int64
#  6   main_genre         246 non-null    object
#  7   main_production    246 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 15.5+ KB

# %%
best_shows_netflix.describe()
# Out:
#        release_year       score  number_of_votes    duration  \
# count    246.000000  246.000000     2.460000e+02  246.000000
# mean    2014.760163    8.093496     1.019668e+05   41.918699
# std        6.392869    0.449261     1.688746e+05   15.242579
# min     1969.000000    7.500000     1.002400e+04   16.000000
# 25%     2013.000000    7.700000     1.855325e+04   27.250000
# 50%     2016.500000    8.000000     4.194250e+04   44.000000
# 75%     2019.000000    8.400000     1.128118e+05   51.750000
# max     2022.000000    9.500000     1.727694e+06  141.000000
#
#        number_of_seasons
# count         246.000000
# mean            3.650407
# std             3.191785
# min             1.000000
# 25%             1.000000
# 50%             3.000000
# 75%             5.000000
# max            21.000000

# %%
raw_credits
# Out:
#        person_id         id                    name                character  \
# 0           3748    tm84618          Robert De Niro            Travis Bickle
# 1          14658    tm84618            Jodie Foster            Iris Steensma
# 2           7064    tm84618           Albert Brooks                      Tom
# 3           3739    tm84618           Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618         Cybill Shepherd                    Betsy
# ...          ...        ...                     ...                      ...
# 77208    1347054  tm1098060  Nnenna Rachael Okonkwo                   Afinni
# 77209     157590  tm1098060           Lucien Morgan           Dr. Ian Stones
# 77210     129059  tm1098060        Magdalena Korpas                     Jane
# 77211    2050199  tm1098060        Mistura Olusanya               Nurse Titi
# 77212    2050423  tm1098060              Yemi Amodu                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# 4         ACTOR
# ...         ...
# 77208     ACTOR
# 77209     ACTOR
# 77210     ACTOR
# 77211     ACTOR
# 77212  DIRECTOR
#
# [77213 rows x 5 columns]

# %%
raw_credits.shape
# Out:
# (77213, 5)

# %%
raw_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77213 entries, 0 to 77212
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77213 non-null  int64
#  1   id         77213 non-null  object
#  2   name       77213 non-null  object
#  3   character  67586 non-null  object
#  4   role       77213 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.9+ MB

# %%
raw_credits.isnull().any()
# Out:
# person_id    False
# id           False
# name         False
# character     True
# role         False
# dtype: bool

# %%
raw_credits.describe()
# Out:
#           person_id
# count  7.721300e+04
# mean   4.994603e+05
# std    6.128431e+05
# min    7.000000e+00
# 25%    4.158400e+04
# 50%    1.829850e+05
# 75%    8.415570e+05
# max    2.371585e+06

# %%
raw_titles
# Out:
#              id                                title   type  release_year  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1       tm84618                          Taxi Driver  MOVIE          1976
# 2      tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 3       tm70993                        Life of Brian  MOVIE          1979
# 4      tm190788                         The Exorcist  MOVIE          1973
# ...         ...                                  ...    ...           ...
# 5801  tm1014599                            Fine Wine  MOVIE          2021
# 5802  tm1108171                       Edis Starlight  MOVIE          2021
# 5803  tm1045018                                Clash  MOVIE          2021
# 5804  tm1098060                       Shadow Parties  MOVIE          2021
# 5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW          2021
#
#      age_certification  runtime                             genres  \
# 0                TV-MA       48                  ['documentation']
# 1                    R      113                 ['crime', 'drama']
# 2                   PG       91              ['comedy', 'fantasy']
# 3                    R       94                         ['comedy']
# 4                    R      133                         ['horror']
# ...                ...      ...                                ...
# 5801               NaN      100               ['romance', 'drama']
# 5802               NaN       74         ['music', 'documentation']
# 5803               NaN       88                ['family', 'drama']
# 5804               NaN      116             ['action', 'thriller']
# 5805               NaN        0  ['family', 'comedy', 'animation']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes
# 0                  ['US']      1.0         NaN         NaN         NaN
# 1                  ['US']      NaN   tt0075314         8.3    795222.0
# 2                  ['GB']      NaN   tt0071853         8.2    530877.0
# 3                  ['GB']      NaN   tt0079470         8.0    392419.0
# 4                  ['US']      NaN   tt0070047         8.1    391942.0
# ...                   ...      ...         ...         ...         ...
# 5801               ['NG']      NaN  tt13857480         6.9        39.0
# 5802                   []      NaN         NaN         NaN         NaN
# 5803         ['NG', 'CA']      NaN  tt14620732         6.5        32.0
# 5804                   []      NaN  tt10168094         6.2         9.0
# 5805                   []      1.0  tt13711094         8.8        16.0
#
# [5806 rows x 12 columns]

# %%
raw_titles.shape
# Out:
# (5806, 12)

# %%
raw_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5806 non-null   object
#  1   title                 5805 non-null   object
#  2   type                  5806 non-null   object
#  3   release_year          5806 non-null   int64
#  4   age_certification     3196 non-null   object
#  5   runtime               5806 non-null   int64
#  6   genres                5806 non-null   object
#  7   production_countries  5806 non-null   object
#  8   seasons               2047 non-null   float64
#  9   imdb_id               5362 non-null   object
#  10  imdb_score            5283 non-null   float64
#  11  imdb_votes            5267 non-null   float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 544.4+ KB

# %%
raw_titles.isnull().any()
# Out:
# id                      False
# title                    True
# type                    False
# release_year            False
# age_certification        True
# runtime                 False
# genres                  False
# production_countries    False
# seasons                  True
# imdb_id                  True
# imdb_score               True
# imdb_votes               True
# dtype: bool

# %%
raw_titles.isnull().sum()/len(raw_titles)
# Out:
# id                      0.000000
# title                   0.000172
# type                    0.000000
# release_year            0.000000
# age_certification       0.449535
# runtime                 0.000000
# genres                  0.000000
# production_countries    0.000000
# seasons                 0.647434
# imdb_id                 0.076473
# imdb_score              0.090079
# imdb_votes              0.092835
# dtype: float64

# %%
raw_titles.drop('age_certification', axis = 1, inplace = True)

# %%
raw_titles.columns
# Out:
# Index(['id', 'title', 'type', 'release_year', 'runtime', 'genres',
#        'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes'],
#       dtype='object')

# %%
raw_titles.drop('seasons', axis = 1, inplace = True)

# %%
raw_titles.columns
# Out:
# Index(['id', 'title', 'type', 'release_year', 'runtime', 'genres',
#        'production_countries', 'imdb_id', 'imdb_score', 'imdb_votes'],
#       dtype='object')

# %%
raw_titles['title'].value_counts()
# Out:
# The Gift                              3
# Connected                             3
# The Heirs                             2
# Manhunt                               2
# The Platform                          2
#                                      ..
# Troy: Fall of a City                  1
# To All the Boys I've Loved Before     1
# Extinction                            1
# When We First Met                     1
# Mighty Little Bheem: Kite Festival    1
# Name: title, Length: 5751, dtype: int64

# %%
raw_titles.dropna(subset = 'title', axis = 0, inplace = True)

# %%
raw_titles['title'].isnull().any()
# Out:
# False

# %%
raw_titles['imdb_score'].mean()
# Out:
# 6.5334469051675175

# %%
raw_titles['imdb_score'].median()
# Out:
# 6.6

# %%
raw_titles['imdb_score'].fillna(raw_titles['imdb_score'].median(), inplace = True) # By considering outlier in the data we are using median(centre value) for filling the data with missing values.

# %%
raw_titles['imdb_score'].isnull().sum()
# Out:
# 0

# %%
raw_titles['imdb_votes'].mean()
# Out:
# 23407.194987659008

# %%
raw_titles['imdb_votes'].median()
# Out:
# 2279.0

# %%
raw_titles['imdb_votes'].fillna(raw_titles['imdb_votes'].median(), inplace = True)

# %%
raw_titles['imdb_votes'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Does runtime dependent on imdb_score and imdb_votes**

# %%
raw_titles.groupby(['runtime'])[['imdb_score', 'imdb_votes']].aggregate(['count'])
# Out:
#         imdb_score imdb_votes
#              count      count
# runtime
# 0               24         24
# 2                4          4
# 3                8          8
# 4                5          5
# 5                7          7
# ...            ...        ...
# 229              1          1
# 230              1          1
# 235              1          1
# 240              1          1
# 251              1          1
#
# [205 rows x 2 columns]

# %%
raw_titles = raw_titles[raw_titles['runtime']!=0]

# %%
raw_titles.groupby(['runtime'])[['imdb_score', 'imdb_votes']].aggregate(['count'])
# Out:
#         imdb_score imdb_votes
#              count      count
# runtime
# 2                4          4
# 3                8          8
# 4                5          5
# 5                7          7
# 6               11         11
# ...            ...        ...
# 229              1          1
# 230              1          1
# 235              1          1
# 240              1          1
# 251              1          1
#
# [204 rows x 2 columns]

# %%
sns.scatterplot('runtime', 'imdb_score', data = raw_titles);
# Out:
# c:\users\240g_w10\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot('runtime', 'imdb_votes', data = raw_titles)
# Out:
# c:\users\240g_w10\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='runtime', ylabel='imdb_votes'>

# %%
raw_titles.groupby(['type'])[['imdb_score']].aggregate([max])
# Out:
#       imdb_score
#              max
# type
# MOVIE        9.0
# SHOW         9.6

# %%
raw_titles['type'].unique()
# Out:
# array(['SHOW', 'MOVIE'], dtype=object)

# %% [markdown]
# **Plot Distribution for MOVIE**

# %%
movie = raw_titles.loc[raw_titles['type']== 'MOVIE', 'imdb_score']
movie
# Out:
# 1       8.3
# 2       8.2
# 3       8.0
# 4       8.1
# 6       7.7
#        ...
# 5800    5.8
# 5801    6.9
# 5802    6.6
# 5803    6.5
# 5804    6.2
# Name: imdb_score, Length: 3758, dtype: float64

# %%
plt.hist(x = movie, bins = 10)
plt.xlabel('imdb_score')
plt.ylabel('Frequency');

# %%
# In this histogram plot we can observe that imdb_score started at 0.8 and ended at 9 and  we can observe that imdb_score rated high i,e 6.5 for more than 1400 movies

# %%
show = raw_titles.loc[raw_titles['type']=='SHOW', 'imdb_score']
show
# Out:
# 0       6.6
# 5       8.8
# 29      8.1
# 47      8.9
# 55      6.9
#        ...
# 5785    5.1
# 5793    6.6
# 5794    6.6
# 5796    4.6
# 5799    6.6
# Name: imdb_score, Length: 2023, dtype: float64

# %%
plt.hist(x = show, bins = 10)
plt.xlabel('imdb_score')
plt.ylabel('Frequency');

# %%
# The above histogram says that imdb_score for show started at 0.8 and ended at 9.6, comparing to Movie imdb_score Show imdb_score is more and 
# also we can observe that imdb_score is higher i,e 7 for shows more than 700

# %%
new_type = raw_titles['type'].value_counts()
new_type
# Out:
# MOVIE    3758
# SHOW     2023
# Name: type, dtype: int64

# %%
plt.pie(x =new_type, labels = new_type.index, autopct = '%.2f%%', data = raw_titles)
plt.style.use('seaborn')
plt.legend();

# %%
plt.hist(x = movie, bins =10, alpha = 0.8, label = 'movie')
plt.hist(x = show, bins = 10, alpha = 0.8, label = 'show')
plt.xlabel('imdb_score')
plt.ylabel('Frequency');
plt.legend();

# %%
raw_titles.head(10)
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1   tm84618                          Taxi Driver  MOVIE          1976
# 2  tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 3   tm70993                        Life of Brian  MOVIE          1979
# 4  tm190788                         The Exorcist  MOVIE          1973
# 5   ts22164         Monty Python's Flying Circus   SHOW          1969
# 6   tm14873                          Dirty Harry  MOVIE          1971
# 7  tm185072                         My Fair Lady  MOVIE          1964
# 8   tm98978                      The Blue Lagoon  MOVIE          1980
# 9  tm119281                     Bonnie and Clyde  MOVIE          1967
#
#    runtime                                   genres production_countries  \
# 0       48                        ['documentation']               ['US']
# 1      113                       ['crime', 'drama']               ['US']
# 2       91                    ['comedy', 'fantasy']               ['GB']
# 3       94                               ['comedy']               ['GB']
# 4      133                               ['horror']               ['US']
# 5       30                   ['comedy', 'european']               ['GB']
# 6      102          ['thriller', 'crime', 'action']               ['US']
# 7      170  ['drama', 'music', 'romance', 'family']               ['US']
# 8      104                     ['romance', 'drama']               ['US']
# 9      110             ['drama', 'crime', 'action']               ['US']
#
#      imdb_id  imdb_score  imdb_votes
# 0        NaN         6.6      2279.0
# 1  tt0075314         8.3    795222.0
# 2  tt0071853         8.2    530877.0
# 3  tt0079470         8.0    392419.0
# 4  tt0070047         8.1    391942.0
# 5  tt0063929         8.8     72895.0
# 6  tt0066999         7.7    153463.0
# 7  tt0058385         7.8     94121.0
# 8  tt0080453         5.8     69053.0
# 9  tt0061418         7.7    111189.0

# %%
import re
production = raw_titles['production_countries'].apply(lambda x : re.sub('[^A-Z,]+', '', x))
production
# Out:
# 0          US
# 1          US
# 2          GB
# 3          GB
# 4          US
#         ...
# 5800       PH
# 5801       NG
# 5802
# 5803    NG,CA
# 5804
# Name: production_countries, Length: 5781, dtype: object

# %%
production = raw_titles['production_countries'].apply(lambda x : re.sub('[^A-Z]+', ' ', x))
production
# Out:
# 0           US
# 1           US
# 2           GB
# 3           GB
# 4           US
#          ...
# 5800        PH
# 5801        NG
# 5802
# 5803     NG CA
# 5804
# Name: production_countries, Length: 5781, dtype: object

# %%
production.value_counts()
# Out:
#  US              1940
#  IN               604
#  JP               265
#                   226
#  GB               219
#                  ...
#  PR US GB CN        1
#  GB US FR           1
#  IT ES FR           1
#  GB US CZ           1
#  NG CA              1
# Name: production_countries, Length: 448, dtype: int64

# %%
production = production.replace(' ', np.nan)
production
# Out:
# 0           US
# 1           US
# 2           GB
# 3           GB
# 4           US
#          ...
# 5800        PH
# 5801        NG
# 5802        NaN
# 5803     NG CA
# 5804        NaN
# Name: production_countries, Length: 5781, dtype: object

# %%
production.unique()
# Out:
# array([' US ', ' GB ', ' US GB ', ' JP ', ' EG ', ' DE ', ' IN ', nan,
#        ' DZ EG ', ' LB ', ' FR LB CA ', ' IN SU ', ' US IT ', ' HK US ',
#        ' GB US ', ' AR ', ' KW ', ' EG FR ', ' FR LB ', ' US JP ',
#        ' US CA ', ' DE US ', ' US DE ', ' CA US ', ' US FR ',
#        ' PE US BR ', ' IT US FR ', ' US HK ', ' FR IE GB DE ',
#        ' GH GB US BF DE ', ' AR ES ', ' FR ', ' MX ', ' AU ', ' CO ',
#        ' BE FR NO LB ', ' IT LB BE FR ', ' US FR DE PS ', ' TR ', ' CA ',
#        ' GB US BS CZ DE ', ' GB US AU ', ' DE ES US FR ', ' GB US AU DE ',
#        ' JP US ', ' US IS GB ', ' DK ', ' NZ JP US ', ' US CA FR ',
#        ' GB US DE ', ' US DE IT GB ', ' CA DE US ', ' HK CN ', ' IT US ',
#        ' FR JP US ', ' US BE ', ' KR ', ' IT ', ' BG GB US ', ' US AU ',
#        ' ES GB ', ' GB US JP ', ' CN HK ', ' RU ', ' CN ', ' SG ',
#        ' GB US CA ', ' HK JP ', ' CA GB US ', ' ES FR MX ', ' IN CA US ',
#        ' PS FR MA DE ', ' HK ', ' DE UY ES AR ', ' ES AR ', ' US IN ',
#        ' TW ', ' IN US ', ' MY ', ' ES CH PS BE FR ', ' CL AR ',
#        ' DE KW PS FR ', ' CL ', ' NG ', ' PS ', ' GB FR LB ', ' ZA ',
#        ' SA ', ' NG GB US AT FR DE ', ' LB FR ', ' GB DK NL SE CZ ',
#        ' PH ', ' L ', ' TH IN ', ' NG US ', ' XX ', ' US ES ',
#        ' NO SE US ', ' US AE ', ' CA HU US ', ' DK US ', ' NO ',
#        ' GB FR DE ', ' US HU IT ', ' US ZA DE ', ' DE IN ', ' GB NG ',
#        ' AE US LB ', ' ID ', ' NL US AE PS ', ' FR GB US ', ' US DE GB ',
#        ' CA CL US ', ' IL ', ' AU US ', ' US GB CN CA ', ' ES ',
#        ' GB AU CH ', ' FR US ', ' US GB CA ', ' CA KR ', ' CA FR ',
#        ' AT ', ' US DK ', ' US BR ', ' FI ', ' GB US EG ', ' RO ',
#        ' CD GB ', ' BR ', ' US CA JP ', ' PL ', ' VE AR ',
#        ' IL NO ZA AE GB IS IE ', ' UA US CN DE SG ', ' AE LB ',
#        ' IT PS FR DE ', ' NZ ', ' UA ', ' BE FR ', ' US CN ',
#        ' US FR GB ', ' GB IT ', ' MX ZA US ', ' ES US GB ',
#        ' GB IR JO QA ', ' DE GB US BE DK ', ' UA GB US ', ' US FR LU GB ',
#        ' US CH ', ' US GH ', ' IE ZA ', ' CA DE GB ', ' GB IE ',
#        ' US CA GB ', ' IS ', ' FR GB ', ' SE CA FI FR DE ', ' BG ',
#        ' BY ', ' MA US ', ' IE ', ' CA CN FR ', ' DE AU FR ', ' SK CZ ',
#        ' QA FR ', ' QA PS AE FR JO LB ', ' MA FR ', ' NL ', ' SE ',
#        ' HR ', ' ES FR ', ' SE US ', ' FR BE ', ' SY GB ', ' NO SE ',
#        ' GL FR ', ' US AT ', ' AE ', ' CD ', ' FR PT SE DK BR ',
#        ' ES DK ', ' AU GB ', ' AU US GB ', ' LB QA ', ' FR DE PS ',
#        ' PK ', ' GB IN ', ' JP US CA ', ' CL FR ', ' CZ ', ' VN ',
#        ' GB NL ', ' CA NG ', ' FR RU US ', ' CA HU MX ES GB US ',
#        ' US FR NL GB ', ' CA US CN ', ' GB CA ', ' FR CA ', ' KR US ',
#        ' MX US ', ' BE FR GB ', ' IN CN US GB ', ' BE FR US ',
#        ' GB US CZ ', ' IT ES FR ', ' GB US FR ', ' PR US GB CN ',
#        ' SG US GB ID CA CN ', ' GB US SG ', ' GB DE ', ' HK IS US ',
#        ' IT CH FR ', ' US FR IR ', ' NO US IS ', ' IQ GB ', ' BE ',
#        ' HU ', ' DE CA US ', ' IE CA ', ' PR ', ' BG US ', ' KH US ',
#        ' US GB ES ', ' CN US ES ', ' FR GE DE ', ' GB US DK ', ' TH ',
#        ' NL BE ', ' CN US CA ', ' IL MA US BG GB ', ' FR LU US ',
#        ' JP FR ', ' BE FR IT ', ' TR US ', ' ES IT ', ' BR CA ',
#        ' CA CN ', ' ES US ', ' CU US ', ' ZA GB ', ' CA GB ', ' US PL ',
#        ' ES DE ', ' CA US IE ', ' IS SE BE ', ' CH DE ', ' CN JP ',
#        ' US MX ', ' DK NL NO SE ', ' NZ GB DE ', ' AR ES UY ',
#        ' LU CA FR ', ' KE ', ' KR FR JP ', ' MX ES ', ' US DE ZA ',
#        ' GB IS ', ' FR IN ', ' IT CH VA FR DE ', ' DE NO PE ', ' US NG ',
#        ' SG PH ', ' DE IT ', ' NL US ', ' RU RS PL ', ' FR IT ',
#        ' AE SA SY ', ' GB DE DK NL ', ' GB US IL IT PE ', ' FR ES ',
#        ' PL CH AL IT ', ' PE ', ' SG ID MY ', ' KH ', ' IN MX ',
#        ' FR AR ', ' CZ US ', ' BE GB US ', ' TZ ', ' QA TN BE FR ',
#        ' MX FI ', ' AR BR DK FR DE PL ', ' TW US CN FR ', ' GE ',
#        ' CL NL FR ', ' BE ES ', ' NL MX ', ' CA ZA US ', ' ZW ',
#        ' AT IQ US ', ' PY ', ' IT AR ', ' AR US ', ' FR IN SG ',
#        ' FR PS CH QA ', ' NL JO DE ', ' TW US ', ' MX AR ', ' GH ',
#        ' AR IT ', ' MX CO ', ' LB PS ', ' IN NP ', ' CA JP US ',
#        ' DK GR GB ', ' CM ', ' CL MX US ', ' IN BD ', ' NO NG ', ' CH ',
#        ' KG ', ' ZA CA ', ' US CN AU ', ' BD ', ' JP GB ', ' LT NL BE ',
#        ' CA CN US ', ' US BG ', ' US FR IE ', ' HU US CA ', ' US CY ',
#        ' FR LT GB ', ' CN US ', ' GB FR ', ' SN BE FR ', ' BE SE GB ',
#        ' MW GB US ', ' US IL ', ' PT US ', ' IE GB ', ' FR ES US CA ',
#        ' US FR SE GB DE DK CA ', ' TH US ', ' LU ', ' CZ FR GB ',
#        ' NO FI ', ' US CN TH ', ' GB US CN ', ' CH US ', ' BR FR ES BE ',
#        ' DE AT ', ' IN GB ', ' BR MX ', ' AR ES FR ', ' US AL JO TH ',
#        ' IL US FR DE ', ' IT GB ', ' IO ', ' CN DE GB ',
#        ' UA GB US NL PL ', ' MU ', ' DE ES ', ' BE KH FR LU ', ' JO ',
#        ' PS QA ', ' ES BE DE ', ' RS UY AR ', ' FR US JP ', ' SG FR NL ',
#        ' JP US CN ', ' ES MX ', ' PE AR ', ' ES PT ', ' AT DE ',
#        ' US AR ', ' MY TW ', ' DE NO ', ' PH US ', ' ES CO ',
#        ' FR ES US ', ' AR CA CL ', ' EG US ', ' ES US BE ', ' CN ES ',
#        ' FR JP GB US CA ', ' MX CO FR ', ' US SE ', ' FR BR ', ' CA LK ',
#        ' FR QA MA ', ' IE US ', ' UY ', ' AO ZA ', ' DE IN AT ',
#        ' GT UY ', ' AR CO ', ' QA SY FR LB ', ' SN ', ' MZ ',
#        ' DK EG DE ', ' SG MY ', ' US NL CA LB ', ' JP US FR ',
#        ' AF DE PS ', ' FR IN QA ', ' PS DK LB ', ' US GB DE ',
#        ' UY MX ES ', ' HK PH ', ' CA NO ', ' CN TW ', ' EG SA ',
#        ' LB GB DK ', ' NL PS US LB ', ' NA ', ' PH JP ',
#        ' CA GR NZ GB AU ', ' GB US GR ', ' US AT GB ', ' DK IS ',
#        ' DE GB US ', ' FR DE US ', ' JP TH US ', ' GB SE ', ' RO US ',
#        ' PL KR US ', ' QA MX US CH AR BR DE ', ' CA IE US ', ' FR LU ',
#        ' PT ', ' US NL ', ' IN SG US ', ' BR IT ', ' HU NL CH GB ',
#        ' CL PE ', ' PE ES ', ' BR US ', ' BE GB DE ', ' US CA CN ',
#        ' ZA US ', ' US ZA GB ', ' AF ', ' NZ HK ', ' CZ DE ', ' BE LU ',
#        ' CA ZA ', ' RO SE ', ' RU US ', ' CN GB ', ' DE FR ', ' HU CA ',
#        ' IL US ', ' BE DE ', ' PH FO ', ' TZ GB ', ' NG CA '],
#       dtype=object)

# %%
unique_words = []
for i in production:
    for j in str(i).split(','):
        if j not in unique_words:
            unique_words.append(j)

# %%
unique_words
# Out:
# [' US ',
#  ' GB ',
#  ' US GB ',
#  ' JP ',
#  ' EG ',
#  ' DE ',
#  ' IN ',
#  'nan',
#  ' DZ EG ',
#  ' LB ',
#  ' FR LB CA ',
#  ' IN SU ',
#  ' US IT ',
#  ' HK US ',
#  ' GB US ',
#  ' AR ',
#  ' KW ',
#  ' EG FR ',
#  ' FR LB ',
#  ' US JP ',
#  ' US CA ',
#  ' DE US ',
#  ' US DE ',
#  ' CA US ',
#  ' US FR ',
#  ' PE US BR ',
#  ' IT US FR ',
#  ' US HK ',
#  ' FR IE GB DE ',
#  ' GH GB US BF DE ',
#  ' AR ES ',
#  ' FR ',
#  ' MX ',
#  ' AU ',
#  ' CO ',
#  ' BE FR NO LB ',
#  ' IT LB BE FR ',
#  ' US FR DE PS ',
#  ' TR ',
#  ' CA ',
#  ' GB US BS CZ DE ',
#  ' GB US AU ',
#  ' DE ES US FR ',
#  ' GB US AU DE ',
#  ' JP US ',
#  ' US IS GB ',
#  ' DK ',
#  ' NZ JP US ',
#  ' US CA FR ',
#  ' GB US DE ',
#  ' US DE IT GB ',
#  ' CA DE US ',
#  ' HK CN ',
#  ' IT US ',
#  ' FR JP US ',
#  ' US BE ',
#  ' KR ',
#  ' IT ',
#  ' BG GB US ',
#  ' US AU ',
#  ' ES GB ',
#  ' GB US JP ',
#  ' CN HK ',
#  ' RU ',
#  ' CN ',
#  ' SG ',
#  ' GB US CA ',
#  ' HK JP ',
#  ' CA GB US ',
#  ' ES FR MX ',
#  ' IN CA US ',
#  ' PS FR MA DE ',
#  ' HK ',
#  ' DE UY ES AR ',
#  ' ES AR ',
#  ' US IN ',
#  ' TW ',
#  ' IN US ',
#  ' MY ',
#  ' ES CH PS BE FR ',
#  ' CL AR ',
#  ' DE KW PS FR ',
#  ' CL ',
#  ' NG ',
#  ' PS ',
#  ' GB FR LB ',
#  ' ZA ',
#  ' SA ',
#  ' NG GB US AT FR DE ',
#  ' LB FR ',
#  ' GB DK NL SE CZ ',
#  ' PH ',
#  ' L ',
#  ' TH IN ',
#  ' NG US ',
#  ' XX ',
#  ' US ES ',
#  ' NO SE US ',
#  ' US AE ',
#  ' CA HU US ',
#  ' DK US ',
#  ' NO ',
#  ' GB FR DE ',
#  ' US HU IT ',
#  ' US ZA DE ',
#  ' DE IN ',
#  ' GB NG ',
#  ' AE US LB ',
#  ' ID ',
#  ' NL US AE PS ',
#  ' FR GB US ',
#  ' US DE GB ',
#  ' CA CL US ',
#  ' IL ',
#  ' AU US ',
#  ' US GB CN CA ',
#  ' ES ',
#  ' GB AU CH ',
#  ' FR US ',
#  ' US GB CA ',
#  ' CA KR ',
#  ' CA FR ',
#  ' AT ',
#  ' US DK ',
#  ' US BR ',
#  ' FI ',
#  ' GB US EG ',
#  ' RO ',
#  ' CD GB ',
#  ' BR ',
#  ' US CA JP ',
#  ' PL ',
#  ' VE AR ',
#  ' IL NO ZA AE GB IS IE ',
#  ' UA US CN DE SG ',
#  ' AE LB ',
#  ' IT PS FR DE ',
#  ' NZ ',
#  ' UA ',
#  ' BE FR ',
#  ' US CN ',
#  ' US FR GB ',
#  ' GB IT ',
#  ' MX ZA US ',
#  ' ES US GB ',
#  ' GB IR JO QA ',
#  ' DE GB US BE DK ',
#  ' UA GB US ',
#  ' US FR LU GB ',
#  ' US CH ',
#  ' US GH ',
#  ' IE ZA ',
#  ' CA DE GB ',
#  ' GB IE ',
#  ' US CA GB ',
#  ' IS ',
#  ' FR GB ',
#  ' SE CA FI FR DE ',
#  ' BG ',
#  ' BY ',
#  ' MA US ',
#  ' IE ',
#  ' CA CN FR ',
#  ' DE AU FR ',
#  ' SK CZ ',
#  ' QA FR ',
#  ' QA PS AE FR JO LB ',
#  ' MA FR ',
#  ' NL ',
#  ' SE ',
#  ' HR ',
#  ' ES FR ',
#  ' SE US ',
#  ' FR BE ',
#  ' SY GB ',
#  ' NO SE ',
#  ' GL FR ',
#  ' US AT ',
#  ' AE ',
#  ' CD ',
#  ' FR PT SE DK BR ',
#  ' ES DK ',
#  ' AU GB ',
#  ' AU US GB ',
#  ' LB QA ',
#  ' FR DE PS ',
#  ' PK ',
#  ' GB IN ',
#  ' JP US CA ',
#  ' CL FR ',
#  ' CZ ',
#  ' VN ',
#  ' GB NL ',
#  ' CA NG ',
#  ' FR RU US ',
#  ' CA HU MX ES GB US ',
#  ' US FR NL GB ',
#  ' CA US CN ',
#  ' GB CA ',
#  ' FR CA ',
#  ' KR US ',
#  ' MX US ',
#  ' BE FR GB ',
#  ' IN CN US GB ',
#  ' BE FR US ',
#  ' GB US CZ ',
#  ' IT ES FR ',
#  ' GB US FR ',
#  ' PR US GB CN ',
#  ' SG US GB ID CA CN ',
#  ' GB US SG ',
#  ' GB DE ',
#  ' HK IS US ',
#  ' IT CH FR ',
#  ' US FR IR ',
#  ' NO US IS ',
#  ' IQ GB ',
#  ' BE ',
#  ' HU ',
#  ' DE CA US ',
#  ' IE CA ',
#  ' PR ',
#  ' BG US ',
#  ' KH US ',
#  ' US GB ES ',
#  ' CN US ES ',
#  ' FR GE DE ',
#  ' GB US DK ',
#  ' TH ',
#  ' NL BE ',
#  ' CN US CA ',
#  ' IL MA US BG GB ',
#  ' FR LU US ',
#  ' JP FR ',
#  ' BE FR IT ',
#  ' TR US ',
#  ' ES IT ',
#  ' BR CA ',
#  ' CA CN ',
#  ' ES US ',
#  ' CU US ',
#  ' ZA GB ',
#  ' CA GB ',
#  ' US PL ',
#  ' ES DE ',
#  ' CA US IE ',
#  ' IS SE BE ',
#  ' CH DE ',
#  ' CN JP ',
#  ' US MX ',
#  ' DK NL NO SE ',
#  ' NZ GB DE ',
#  ' AR ES UY ',
#  ' LU CA FR ',
#  ' KE ',
#  ' KR FR JP ',
#  ' MX ES ',
#  ' US DE ZA ',
#  ' GB IS ',
#  ' FR IN ',
#  ' IT CH VA FR DE ',
#  ' DE NO PE ',
#  ' US NG ',
#  ' SG PH ',
#  ' DE IT ',
#  ' NL US ',
#  ' RU RS PL ',
#  ' FR IT ',
#  ' AE SA SY ',
#  ' GB DE DK NL ',
#  ' GB US IL IT PE ',
#  ' FR ES ',
#  ' PL CH AL IT ',
#  ' PE ',
#  ' SG ID MY ',
#  ' KH ',
#  ' IN MX ',
#  ' FR AR ',
#  ' CZ US ',
#  ' BE GB US ',
#  ' TZ ',
#  ' QA TN BE FR ',
#  ' MX FI ',
#  ' AR BR DK FR DE PL ',
#  ' TW US CN FR ',
#  ' GE ',
#  ' CL NL FR ',
#  ' BE ES ',
#  ' NL MX ',
#  ' CA ZA US ',
#  ' ZW ',
#  ' AT IQ US ',
#  ' PY ',
#  ' IT AR ',
#  ' AR US ',
#  ' FR IN SG ',
#  ' FR PS CH QA ',
#  ' NL JO DE ',
#  ' TW US ',
#  ' MX AR ',
#  ' GH ',
#  ' AR IT ',
#  ' MX CO ',
#  ' LB PS ',
#  ' IN NP ',
#  ' CA JP US ',
#  ' DK GR GB ',
#  ' CM ',
#  ' CL MX US ',
#  ' IN BD ',
#  ' NO NG ',
#  ' CH ',
#  ' KG ',
#  ' ZA CA ',
#  ' US CN AU ',
#  ' BD ',
#  ' JP GB ',
#  ' LT NL BE ',
#  ' CA CN US ',
#  ' US BG ',
#  ' US FR IE ',
#  ' HU US CA ',
#  ' US CY ',
#  ' FR LT GB ',
#  ' CN US ',
#  ' GB FR ',
#  ' SN BE FR ',
#  ' BE SE GB ',
#  ' MW GB US ',
#  ' US IL ',
#  ' PT US ',
#  ' IE GB ',
#  ' FR ES US CA ',
#  ' US FR SE GB DE DK CA ',
#  ' TH US ',
#  ' LU ',
#  ' CZ FR GB ',
#  ' NO FI ',
#  ' US CN TH ',
#  ' GB US CN ',
#  ' CH US ',
#  ' BR FR ES BE ',
#  ' DE AT ',
#  ' IN GB ',
#  ' BR MX ',
#  ' AR ES FR ',
#  ' US AL JO TH ',
#  ' IL US FR DE ',
#  ' IT GB ',
#  ' IO ',
#  ' CN DE GB ',
#  ' UA GB US NL PL ',
#  ' MU ',
#  ' DE ES ',
#  ' BE KH FR LU ',
#  ' JO ',
#  ' PS QA ',
#  ' ES BE DE ',
#  ' RS UY AR ',
#  ' FR US JP ',
#  ' SG FR NL ',
#  ' JP US CN ',
#  ' ES MX ',
#  ' PE AR ',
#  ' ES PT ',
#  ' AT DE ',
#  ' US AR ',
#  ' MY TW ',
#  ' DE NO ',
#  ' PH US ',
#  ' ES CO ',
#  ' FR ES US ',
#  ' AR CA CL ',
#  ' EG US ',
#  ' ES US BE ',
#  ' CN ES ',
#  ' FR JP GB US CA ',
#  ' MX CO FR ',
#  ' US SE ',
#  ' FR BR ',
#  ' CA LK ',
#  ' FR QA MA ',
#  ' IE US ',
#  ' UY ',
#  ' AO ZA ',
#  ' DE IN AT ',
#  ' GT UY ',
#  ' AR CO ',
#  ' QA SY FR LB ',
#  ' SN ',
#  ' MZ ',
#  ' DK EG DE ',
#  ' SG MY ',
#  ' US NL CA LB ',
#  ' JP US FR ',
#  ' AF DE PS ',
#  ' FR IN QA ',
#  ' PS DK LB ',
#  ' US GB DE ',
#  ' UY MX ES ',
#  ' HK PH ',
#  ' CA NO ',
#  ' CN TW ',
#  ' EG SA ',
#  ' LB GB DK ',
#  ' NL PS US LB ',
#  ' NA ',
#  ' PH JP ',
#  ' CA GR NZ GB AU ',
#  ' GB US GR ',
#  ' US AT GB ',
#  ' DK IS ',
#  ' DE GB US ',
#  ' FR DE US ',
#  ' JP TH US ',
#  ' GB SE ',
#  ' RO US ',
#  ' PL KR US ',
#  ' QA MX US CH AR BR DE ',
#  ' CA IE US ',
#  ' FR LU ',
#  ' PT ',
#  ' US NL ',
#  ' IN SG US ',
#  ' BR IT ',
#  ' HU NL CH GB ',
#  ' CL PE ',
#  ' PE ES ',
#  ' BR US ',
#  ' BE GB DE ',
#  ' US CA CN ',
#  ' ZA US ',
#  ' US ZA GB ',
#  ' AF ',
#  ' NZ HK ',
#  ' CZ DE ',
#  ' BE LU ',
#  ' CA ZA ',
#  ' RO SE ',
#  ' RU US ',
#  ' CN GB ',
#  ' DE FR ',
#  ' HU CA ',
#  ' IL US ',
#  ' BE DE ',
#  ' PH FO ',
#  ' TZ GB ',
#  ' NG CA ']
